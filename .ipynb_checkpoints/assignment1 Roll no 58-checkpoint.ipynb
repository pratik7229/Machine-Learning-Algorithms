# %%
from sklearn import linear_model
import pandas as pd

# %%
x = [[10,9,2,15,10,16,11,16]]
y = [[95,80,10,50,45,98,38,93]]

data = pd.read_csv('/home/pratik/jupyternotebook programs/ml_assignments/hours.csv')
data.plot(kind='scatter', x='hours',y='ache' )
plt.show()

# %%
import matplotlib.pyplot as plt

x = pd.DataFrame(data['hours'])
y = pd.DataFrame(data['ache'])

# %%
plt.scatter(x=x, y=y)

# %%
lr = linear_model.LinearRegression()

# %%
model = lr.fit(x,y)

# %%
y_pred=model.predict([[2]])
y_pred
# Out:
# array([[21.76042518]])

# %%
plt.plot(x, y, 'o')

plt.plot(x, model.predict(x));
plt.show()
